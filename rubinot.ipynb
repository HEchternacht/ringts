# %%
import requests

# %%
from http.cookiejar import CookieJar
from http.cookies import SimpleCookie

cookie_string = "_fbp=fb.2.1754162371722.510739731398540290; _tt_enable_cookie=1; _ttp=01K4MDGWEJ8FQ8246129YSZJY6_.tt.2; _ga=GA1.1.1253834896.1757374267; _ga_JD5ND9M441=deleted; _gcl_au=1.1.339331831.1761963629.1544014074.1765776035.1765776034; PHPSESSID=l5777jdfs6vtt7hk7blsfuqhrd; cf_clearance=ieK48bcQoruJlUiitTqEj6T7PiR8ZiIYIyJVNB2KNaI-1766253315-1.2.1.1-zoz.hzOYxKxu_6AMCb8flNjJHBueDhnMIn_t9AnQZTHKZlRMeH7kAKIj8q6eDYsvz4.qYvt.1BpgVjpqe19YIqZicLTWeN_fEHP22JF2jSjyKSIhxbxtQ0Zt0WrorB1X38HktlM1GsGndy6CSckKQaZT7bjx45eIYWDLP0FagxhqbvJnfIPDJ7aufGARrqxeVC3HfNuTPNuoR54zWEFx9KgHAfCzpqXuL3xSUJs7vwdDHx42iy7V4skF9TUaNLEY; _rdt_uuid=1757326897421.67973003-7902-47ab-88e5-82cdb4797137; _rdt_em=:25711fe6f316468c5bb0979637aa0d245cbaacb5b393cbff6c53496fc9d3a0d6,bac67f4e5cb7c433106f35055676b9a0ab24156020ccffbd8cabc138fb360371,ee78bf523124205bff4771e95e44357d7c2d36e3d668020767d5ae7d2a208483,ee78bf523124205bff4771e95e44357d7c2d36e3d668020767d5ae7d2a208483; ttcsid_D2RH9SBC77UEK08KPNIG=1766253315349::QKt52zjo9HR5sqGkhuyz.42.1766253412226.1; ttcsid=1766253315349::UclO0ZK46if3dsDR07Vz.197.1766253412226.0; _ga_JD5ND9M441=GS2.1.s1766253315$o229$g1$t1766253412$j26$l0$h614447360$d8jiPi9S4CE4FLcy6R9vn1KCM2IAgOwke4g"

cookie_jar = CookieJar()
simple_cookie = SimpleCookie()
simple_cookie.load(cookie_string)

for key, morsel in simple_cookie.items():
    cookie_jar.set_cookie(
        type('Cookie', (), {
            'name': key,
            'value': morsel.value,
            'domain': 'rubinot.com.br',
            'path': '/',
            'secure': False,
            'expires': None,
            'rest': {},
            'version': 0,
            'port': None,
            'port_specified': False,
            'domain_specified': True,
            'domain_initial_dot': False,
            'path_specified': True,
            'discard': True,
            'comment': None,
            'comment_url': None,
            'rfc2109': False
        })()
    )

# %%
cf_clearance="ieK48bcQoruJlUiitTqEj6T7PiR8ZiIYIyJVNB2KNaI-1766253315-1.2.1.1-zoz.hzOYxKxu_6AMCb8flNjJHBueDhnMIn_t9AnQZTHKZlRMeH7kAKIj8q6eDYsvz4.qYvt.1BpgVjpqe19YIqZicLTWeN_fEHP22JF2jSjyKSIhxbxtQ0Zt0WrorB1X38HktlM1GsGndy6CSckKQaZT7bjx45eIYWDLP0FagxhqbvJnfIPDJ7aufGARrqxeVC3HfNuTPNuoR54zWEFx9KgHAfCzpqXuL3xSUJs7vwdDHx42iy7V4skF9TUaNLEY; _rdt_uuid=1757326897421.67973003-7902-47ab-88e5-82cdb4797137; _rdt_em=:25711fe6f316468c5bb0979637aa0d245cbaacb5b393cbff6c53496fc9d3a0d6,bac67f4e5cb7c433106f35055676b9a0ab24156020ccffbd8cabc138fb360371,ee78bf523124205bff4771e95e44357d7c2d36e3d668020767d5ae7d2a208483,ee78bf523124205bff4771e95e44357d7c2d36e3d668020767d5ae7d2a208483; ttcsid_D2RH9SBC77UEK08KPNIG=1766253315349::QKt52zjo9HR5sqGkhuyz.42.1766253412226.1; ttcsid=1766253315349::UclO0ZK46if3dsDR07Vz.197.1766253412226.0; _ga_JD5ND9M441=GS2.1.s1766253315$o229$g1$t1766253412$j26$l0$h614447360$d8jiPi9S4CE4FLcy6R9vn1KCM2IAgOwke4g"
# post https://rubinot.com.br/?subtopic=guilds&page=view

url="https://rubinot.com.br/"
# Use the cookie_jar created in cell 1
session = requests.Session()
session.cookies = cookie_jar
r = requests.post(
    url=url,
    data={
        "GuildName": "Panqmeuqueixo Alliance"
    },
    params={
        "subtopic": "guilds",
        "page": "view"
    },
    headers=headers
)
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base6
# ...
